# %%
# Mode 1 is DAUC, running hourly resolution MILP
from midass.operation.mode1 import run_mode1
# Mode 2 is DAED, running hourly resolution LP using the results from DAUC to obtain LMPs
from midass.operation.mode2 import run_mode2
# Mode 3 is RTUC, running MILP with shorter time resolution with updated state estimation data
from midass.operation.mode3 import run_mode3
# Mode 4 is RTED, running LP with even shorter time resolution with updated state estimation data
from midass.operation.mode4 import run_mode4
# Functions to plot the result figures
from midass.operation.plot import FigurePlot
# Debugger to grab single snapshot of the running
from midass.operation.debugger import single_snapshot

# %%
# Set the solver and work directory with verbose setting
results_mode1 = run_mode1(solver_name = "gurobi",
                    prefix_dir = r"midass/operation/data/18_bus/",
                    verbose = True)
# Out:
# ------------------ Start MIDAS Scheduling ---------------------
#
# -------------- Mode 1 ---------------------
# -------------- Preprocessing...
# Generator 0 flexibility type is determined by the start-up and shut-down time
# Generator 1 flexibility type is determined by the start-up and shut-down time
# Generator 2 flexibility type is determined by the start-up and shut-down time
# Generator 3 flexibility type is determined by the start-up and shut-down time
# -------------- Preprocessing complete.
#
#   DAUC --------------------- Day 0 Objective value: 237032.04511365958
# Energy cost: 237012.5872928355
# Reserve cost: 19.45782082174095
# ------- Congrats! No penalty exists.
#   DAUC --------------------- Day 1 Objective value: 247911.90982250983
# Energy cost: 247889.46046456744
# Reserve cost: 22.44935793421263
# ------- Congrats! No penalty exists.
#   DAUC --------------------- Day 2 Objective value: 258788.47139348905
# Energy cost: 258765.3209653901
# Reserve cost: 23.15042810051648
# ------- Congrats! No penalty exists.
#
# ------------------ End MIDAS Scheduling -------------------

# %%
# Inspect one specific model result
import pyomo.environ as pe
pe.value(results_mode1["DAUC"][1].gen_spin["WESTG1",20])
# Out:
# 0.0

# %%
results_mode2 = run_mode2(solver_name = "gurobi",
                          prefix_dir = r"midass/operation/data/18_bus/",
                          psse_folder = r"18_bus_PSSE/",
                          case_name = r"Case1",
                          run_name = r"Case1_24hr_run_1_CL",
                          close_loop_flag = False, 
                          ess_dispatchable = False, 
                          verbose = True)
# Out:
# ------------------ Start MIDAS Scheduling ---------------------
#
# -------------- Mode 2 ---------------------
# -------------- Preprocessing...
# Generator 0 flexibility type is determined by the start-up and shut-down time
# Generator 1 flexibility type is determined by the start-up and shut-down time
# Generator 2 flexibility type is determined by the start-up and shut-down time
# Generator 3 flexibility type is determined by the start-up and shut-down time
# -------------- Preprocessing complete.
#
#   RTED --------------------- Day 0 Interval 1 Objective value: 7156.176202806667
# Energy cost: 7156.176202806667
# Reserve cost: 0.0
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 2 Objective value: 7118.1880795308325
# Energy cost: 7118.1880795308325
# Reserve cost: 0.0
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 3 Objective value: 7090.617891408333
# Energy cost: 7090.617891408333
# Reserve cost: 0.0
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 4 Objective value: 7076.955922623334
# Energy cost: 7076.955922623334
# Reserve cost: 0.0
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 5 Objective value: 7065.065681795001
# Energy cost: 7065.065681795001
# Reserve cost: 0.0
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 6 Objective value: 7055.101479760833
# Energy cost: 7055.101479760833
# Reserve cost: 0.0
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 7 Objective value: 7045.370737147499
# Energy cost: 7045.370737147499
# Reserve cost: 0.0
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 8 Objective value: 7036.625004789166
# Energy cost: 7036.625004789166
# Reserve cost: 0.0
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 9 Objective value: 7029.395791453333
# Energy cost: 7029.395791453333
# Reserve cost: 0.0
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 10 Objective value: 7022.990640825833
# Energy cost: 7022.990640825833
# Reserve cost: 0.0
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 211 Objective value: 401751579.5243715
# Energy cost: 11292.413945843333
# Reserve cost: 0.11042566250000001
# ------- Penalty summary
# Loss of load: 6.530416666666649 MWh.
#   RTED --------------------- Day 0 Interval 212 Objective value: 452985440.2661197
# Energy cost: 11292.495162783332
# Reserve cost: 0.1042902625
# ------- Penalty summary
# Loss of load: 14.495583333333343 MWh.
#   RTED --------------------- Day 0 Interval 213 Objective value: 497308192.0174241
# Energy cost: 11292.587852523333
# Reserve cost: 0.09623829166666668
# ------- Penalty summary
# Loss of load: 21.751500000000004 MWh.
#   RTED --------------------- Day 0 Interval 214 Objective value: 534213483.1124652
# Energy cost: 11292.69205367
# Reserve cost: 0.08707821666666667
# ------- Penalty summary
# Loss of load: 29.520833333333353 MWh.
#   RTED --------------------- Day 0 Interval 215 Objective value: 564444500.2179277
# Energy cost: 11292.807749963333
# Reserve cost: 0.07684452500000001
# ------- Penalty summary
# Loss of load: 37.78116666666667 MWh.
#   RTED --------------------- Day 0 Interval 216 Objective value: 586861712.3337255
# Energy cost: 11292.934550159167
# Reserve cost: 0.06584193333333334
# ------- Penalty summary
# Loss of load: 41.07833333333332 MWh.
#   RTED --------------------- Day 0 Interval 217 Objective value: 576715376.4440571
# Energy cost: 11293.056760445
# Reserve cost: 0.05396325416666667
# ------- Penalty summary
# Loss of load: 42.0080833333333 MWh.
#   RTED --------------------- Day 0 Interval 218 Objective value: 587591376.5599005
# Energy cost: 11293.1826012925
# Reserve cost: 0.04396581666666668
# ------- Penalty summary
# Loss of load: 43.341249999999995 MWh.
#   RTED --------------------- Day 0 Interval 219 Objective value: 596370709.9987003
# Energy cost: 11293.297023818333
# Reserve cost: 0.03500985416666667
# ------- Penalty summary
# Loss of load: 45.33383333333334 MWh.
#   RTED --------------------- Day 0 Interval 220 Objective value: 602331543.4270625
# Energy cost: 11293.3999811075
# Reserve cost: 0.0270813125
# ------- Penalty summary
# Loss of load: 47.42025000000001 MWh.
#   RTED --------------------- Day 0 Interval 221 Objective value: 606029376.8450239
# Energy cost: 11293.49154485
# Reserve cost: 0.020145683333333338
# ------- Penalty summary
# Loss of load: 49.05558333333331 MWh.
#   RTED --------------------- Day 0 Interval 222 Objective value: 606768793.5858583
# Energy cost: 11293.571657008333
# Reserve cost: 0.01420129166666667
# ------- Penalty summary
# Loss of load: 50.250750000000004 MWh.
#   RTED --------------------- Day 0 Interval 223 Objective value: 605325460.3163083
# Energy cost: 11293.640373133334
# Reserve cost: 0.00926854166666667
# ------- Penalty summary
# Loss of load: 50.84716666666668 MWh.
#   RTED --------------------- Day 0 Interval 224 Objective value: 601845210.369719
# Energy cost: 11293.697686371666
# Reserve cost: 0.005365979166666669
# ------- Penalty summary
# Loss of load: 51.39858333333336 MWh.
#   RTED --------------------- Day 0 Interval 225 Objective value: 597167210.4128399
# Energy cost: 11293.743652159166
# Reserve cost: 0.0025211041666666685
# ------- Penalty summary
# Loss of load: 51.97833333333335 MWh.
#   RTED --------------------- Day 0 Interval 226 Objective value: 590891460.4456283
# Energy cost: 11293.77822823
# Reserve cost: 0.0007334791666666678
# ------- Penalty summary
# Loss of load: 51.933 MWh.
#   RTED --------------------- Day 0 Interval 227 Objective value: 583146043.8014262
# Energy cost: 11293.8014262525
# Reserve cost: 0.0
# ------- Penalty summary
# Loss of load: 52.05891666666665 MWh.
#   RTED --------------------- Day 0 Interval 228 Objective value: 574627877.1469687
# Energy cost: 11293.813635375
# Reserve cost: 0.0
# ------- Penalty summary
# Loss of load: 51.954333333333324 MWh.
#   RTED --------------------- Day 0 Interval 229 Objective value: 564961460.4822204
# Energy cost: 11293.815553765833
# Reserve cost: 0.0
# ------- Penalty summary
# Loss of load: 50.787416666666665 MWh.
#   RTED --------------------- Day 0 Interval 230 Objective value: 554630960.4815398
# Energy cost: 11293.814873235833
# Reserve cost: 0.0
# ------- Penalty summary
# Loss of load: 49.302083333333336 MWh.
#   RTED --------------------- Day 0 Interval 231 Objective value: 545017627.1449714
# Energy cost: 11293.8116380075
# Reserve cost: 0.0
# ------- Penalty summary
# Loss of load: 49.03166666666669 MWh.
#   RTED --------------------- Day 0 Interval 232 Objective value: 536409793.8058736
# Energy cost: 11293.8058735725
# Reserve cost: 0.0
# ------- Penalty summary
# Loss of load: 48.15966666666668 MWh.
#   RTED --------------------- Day 0 Interval 233 Objective value: 527087043.7974232
# Energy cost: 11293.797423185833
# Reserve cost: 0.0
# ------- Penalty summary
# Loss of load: 47.61224999999999 MWh.
#   RTED --------------------- Day 0 Interval 234 Objective value: 517675043.7863441
# Energy cost: 11293.786344134167
# Reserve cost: 0.0
# ------- Penalty summary
# Loss of load: 46.77049999999999 MWh.
#   RTED --------------------- Day 0 Interval 235 Objective value: 507927377.1059463
# Energy cost: 11293.772613015
# Reserve cost: 0.0
# ------- Penalty summary
# Loss of load: 46.16916666666668 MWh.
#   RTED --------------------- Day 0 Interval 236 Objective value: 498349043.7562769
# Energy cost: 11293.756276889168
# Reserve cost: 0.0
# ------- Penalty summary
# Loss of load: 45.12283333333335 MWh.
#   RTED --------------------- Day 0 Interval 237 Objective value: 488555293.73730063
# Energy cost: 11293.737300550833
# Reserve cost: 0.0
# ------- Penalty summary
# Loss of load: 44.232916666666675 MWh.
#   RTED --------------------- Day 0 Interval 238 Objective value: 478937043.715719
# Energy cost: 11293.715718996667
# Reserve cost: 0.0
# ------- Penalty summary
# Loss of load: 43.41483333333334 MWh.
#   RTED --------------------- Day 0 Interval 239 Objective value: 469151377.02483505
# Energy cost: 11293.69150161
# Reserve cost: 0.0
# ------- Penalty summary
# Loss of load: 42.392500000000005 MWh.
#   RTED --------------------- Day 0 Interval 240 Objective value: 459354710.3313295
# Energy cost: 11293.664662816667
# Reserve cost: 0.0
# ------- Penalty summary
# Loss of load: 41.623833333333344 MWh.
#   RTED --------------------- Day 0 Interval 241 Objective value: 449113960.3030676
# Energy cost: 11293.635025183334
# Reserve cost: 0.0013757499999999942
# ------- Penalty summary
# Loss of load: 41.17408333333335 MWh.
#   RTED --------------------- Day 0 Interval 242 Objective value: 438534876.94297796
# Energy cost: 11293.6045943025
# Reserve cost: 0.005050375000000003
# ------- Penalty summary
# Loss of load: 40.69424999999999 MWh.
#   RTED --------------------- Day 0 Interval 243 Objective value: 427563460.2511563
# Energy cost: 11293.573355035
# Reserve cost: 0.011134541666666659
# ------- Penalty summary
# Loss of load: 39.70891666666665 MWh.
#   RTED --------------------- Day 0 Interval 244 Objective value: 415682210.2273483
# Energy cost: 11293.5412828975
# Reserve cost: 0.01939870833333333
# ------- Penalty summary
# Loss of load: 38.74766666666667 MWh.
#   RTED --------------------- Day 0 Interval 245 Objective value: 403745293.5384304
# Energy cost: 11293.508441558333
# Reserve cost: 0.029988749999999998
# ------- Penalty summary
# Loss of load: 37.864583333333336 MWh.
#   RTED --------------------- Day 0 Interval 246 Objective value: 391482293.5176175
# Energy cost: 11293.474815651667
# Reserve cost: 0.042801833333333324
# ------- Penalty summary
# Loss of load: 37.19216666666667 MWh.
#   RTED --------------------- Day 0 Interval 247 Objective value: 378634460.16481787
# Energy cost: 11293.440389095833
# Reserve cost: 0.05776204166666665
# ------- Penalty summary
# Loss of load: 36.37541666666667 MWh.
#   RTED --------------------- Day 0 Interval 248 Objective value: 364967126.8133342
# Energy cost: 11293.405142233334
# Reserve cost: 0.07485849999999998
# ------- Penalty summary
# Loss of load: 35.50458333333336 MWh.
#   RTED --------------------- Day 0 Interval 249 Objective value: 350666793.4631994
# Energy cost: 11293.369089560832
# Reserve cost: 0.09410966666666665
# ------- Penalty summary
# Loss of load: 34.44725000000002 MWh.
#   RTED --------------------- Day 0 Interval 250 Objective value: 336034126.78120184
# Energy cost: 11293.332249984167
# Reserve cost: 0.11561849999999997
# ------- Penalty summary
# Loss of load: 33.618166666666674 MWh.
#   RTED --------------------- Day 0 Interval 251 Objective value: 321038960.1005894
# Energy cost: 11293.294628078333
# Reserve cost: 0.13929470833333332
# ------- Penalty summary
# Loss of load: 32.151750000000014 MWh.
#   RTED --------------------- Day 0 Interval 252 Objective value: 306108793.4216497
# Energy cost: 11293.256236376666
# Reserve cost: 0.16541324999999998
# ------- Penalty summary
# Loss of load: 31.044750000000022 MWh.
#   RTED --------------------- Day 0 Interval 253 Objective value: 290846210.0760493
# Energy cost: 11293.217218703334
# Reserve cost: 0.192164
# ------- Penalty summary
# Loss of load: 30.202666666666687 MWh.
#   RTED --------------------- Day 0 Interval 254 Objective value: 276564126.7289204
# Energy cost: 11293.163294983333
# Reserve cost: 0.23229208333333332
# ------- Penalty summary
# Loss of load: 28.813000000000006 MWh.
#   RTED --------------------- Day 0 Interval 255 Objective value: 263045960.04682714
# Energy cost: 11293.094453423333
# Reserve cost: 0.2857071666666667
# ------- Penalty summary
# Loss of load: 27.77199999999999 MWh.
#   RTED --------------------- Day 0 Interval 256 Objective value: 250881043.36338073
# Energy cost: 11293.0107252
# Reserve cost: 0.352655625
# ------- Penalty summary
# Loss of load: 26.48466666666665 MWh.
#   RTED --------------------- Day 0 Interval 257 Objective value: 239365960.0115832
# Energy cost: 11292.91207355
# Reserve cost: 0.432843125
# ------- Penalty summary
# Loss of load: 25.016749999999984 MWh.
#   RTED --------------------- Day 0 Interval 258 Objective value: 230564570.25352162
# Energy cost: 11292.832658349167
# Reserve cost: 0.420863375
# ------- Penalty summary
# Loss of load: 23.524833333333333 MWh.
#   RTED --------------------- Day 0 Interval 259 Objective value: 222762363.514555
# Energy cost: 11292.7744852825
# Reserve cost: 0.4067365
# ------- Penalty summary
# Loss of load: 22.07508333333332 MWh.
#   RTED --------------------- Day 0 Interval 260 Objective value: 216497218.79471612
# Energy cost: 11292.737576161666
# Reserve cost: 0.390473375
# ------- Penalty summary
# Loss of load: 20.87191666666666 MWh.
#   RTED --------------------- Day 0 Interval 261 Objective value: 212180370.7606708
# Energy cost: 11292.721948718334
# Reserve cost: 0.37205554166666666
# ------- Penalty summary
# Loss of load: 19.452083333333334 MWh.
#   RTED --------------------- Day 0 Interval 262 Objective value: 208736979.7456018
# Energy cost: 11292.727555153333
# Reserve cost: 0.3513800416666666
# ------- Penalty summary
# Loss of load: 18.687999999999988 MWh.
#   RTED --------------------- Day 0 Interval 263 Objective value: 206492426.41628122
# Energy cost: 11292.754410806667
# Reserve cost: 0.3285371666666666
# ------- Penalty summary
# Loss of load: 16.889166666666654 MWh.
#   RTED --------------------- Day 0 Interval 264 Objective value: 204643759.7702719
# Energy cost: 11292.801186651666
# Reserve cost: 0.3024186249999999
# ------- Penalty summary
# Loss of load: 16.76266666666667 MWh.
#   RTED --------------------- Day 0 Interval 265 Objective value: 204569759.8084664
# Energy cost: 11292.867507675
# Reserve cost: 0.2742921249999999
# ------- Penalty summary
# Loss of load: 16.684499999999975 MWh.
#   RTED --------------------- Day 0 Interval 266 Objective value: 202020676.5090356
# Energy cost: 11292.945212876666
# Reserve cost: 0.23048941666666656
# ------- Penalty summary
# Loss of load: 16.648083333333318 MWh.
#   RTED --------------------- Day 0 Interval 267 Objective value: 197254926.53865227
# Energy cost: 11293.034328766667
# Reserve cost: 0.17099016666666655
# ------- Penalty summary
# Loss of load: 16.256916666666655 MWh.
#   RTED --------------------- Day 0 Interval 268 Objective value: 190417343.23064622
# Energy cost: 11293.134868645
# Reserve cost: 0.09577754166666667
# ------- Penalty summary
# Loss of load: 16.786249999999995 MWh.
# PFR_up deficit: 1.8144999999999998 MWh.
# AGC_up deficit: 3.6195516666666667 MWh.
# Spinning reserve deficit: 3.5362183333333337 MWh.
#   RTED --------------------- Day 0 Interval 269 Objective value: 182042843.2518675
# Energy cost: 11293.246867506667
# Reserve cost: 0.005
# ------- Penalty summary
# Loss of load: 16.49133333333333 MWh.
# PFR_up deficit: 3.407583333333333 MWh.
# AGC_up deficit: 0.32088333333333335 MWh.
# Spinning reserve deficit: 3.503633333333333 MWh.
#   RTED --------------------- Day 0 Interval 270 Objective value: 170765316.34038678
# Energy cost: 11293.336220105833
# Reserve cost: 0.004166666666666667
# ------- Penalty summary
# Loss of load: 16.707749999999994 MWh.
# PFR_up deficit: 2.0397350000000003 MWh.
# Spinning reserve deficit: 3.479651666666667 MWh.
#   RTED --------------------- Day 0 Interval 271 Objective value: 157837217.07118562
# Energy cost: 11293.400352301667
# Reserve cost: 0.004166666666666667
# ------- Penalty summary
# Loss of load: 17.375333333333327 MWh.
# PFR_up deficit: 0.36575999999999986 MWh.
# Spinning reserve deficit: 3.46326 MWh.
#   RTED --------------------- Day 0 Interval 272 Objective value: 143074106.77668616
# Energy cost: 11293.43918611
# Reserve cost: 0.004166666666666667
# ------- Penalty summary
# Loss of load: 17.218750000000018 MWh.
# Spinning reserve deficit: 2.097756666666666 MWh.
#   RTED --------------------- Day 0 Interval 273 Objective value: 126076932.79020487
# Energy cost: 11293.452704830834
# Reserve cost: 0.004166666666666667
# ------- Penalty summary
# Loss of load: 17.170333333333343 MWh.
# Spinning reserve deficit: 0.3719666666666666 MWh.
#   RTED --------------------- Day 0 Interval 274 Objective value: 108763584.3968177
# Energy cost: 11278.381754351665
# Reserve cost: 0.015063333333333541
# ------- Penalty summary
# Loss of load: 16.839333333333343 MWh.
#   RTED --------------------- Day 0 Interval 275 Objective value: 91580950.67318991
# Energy cost: 11242.298710714165
# Reserve cost: 0.041145833333333715
# ------- Penalty summary
# Loss of load: 16.81516666666666 MWh.
#   RTED --------------------- Day 0 Interval 276 Objective value: 74741562.68520667
# Energy cost: 11187.608404202501
# Reserve cost: 0.07680246666666704
# ------- Penalty summary
# Loss of load: 14.213583333333341 MWh.
#   RTED --------------------- Day 0 Interval 277 Objective value: 57926308.38648669
# Energy cost: 11099.9349633175
# Reserve cost: 0.11819003333333371
# ------- Penalty summary
# Loss of load: 11.918750000000008 MWh.
#   RTED --------------------- Day 0 Interval 278 Objective value: 43883831.39954172
# Energy cost: 10957.948018364086
# Reserve cost: 0.11819003333333371
# ------- Penalty summary
# Loss of load: 9.81049999999999 MWh.
#   RTED --------------------- Day 0 Interval 279 Objective value: 31964886.758322205
# Energy cost: 10763.306798847083
# Reserve cost: 0.11819003333333371
# ------- Penalty summary
# Loss of load: 7.8824166666666615 MWh.
#   RTED --------------------- Day 0 Interval 280 Objective value: 22154150.70428892
# Energy cost: 10527.252765559917
# Reserve cost: 0.11819003333333371
# ------- Penalty summary
# Loss of load: 6.405749999999993 MWh.
#   RTED --------------------- Day 0 Interval 281 Objective value: 14271472.67349676
# Energy cost: 10265.888640062582
# Reserve cost: 0.11819003333333371
# ------- Penalty summary
# Loss of load: 4.243250000000008 MWh.
# Spinning reserve deficit: 0.4319399999999997 MWh.
#   RTED --------------------- Day 0 Interval 282 Objective value: 7881926.9188056355
# Energy cost: 9950.133948927332
# Reserve cost: 0.11819003333333371
# ------- Penalty summary
# Loss of load: 2.393416666666667 MWh.
# AGC_up deficit: 1.0316166666666664 MWh.
#   RTED --------------------- Day 0 Interval 283 Objective value: 3595131.9120094185
# Energy cost: 9599.127986053081
# Reserve cost: 0.11735670000000038
# ------- Penalty summary
# Loss of load: 0.5976666666666688 MWh.
# Spinning reserve deficit: 1.6339466666666667 MWh.
#   RTED --------------------- Day 0 Interval 284 Objective value: 1098197.6010483413
# Energy cost: 9243.151191642748
# Reserve cost: 0.11652336666666703
# ------- Penalty summary
# PFR_up deficit: 1.151923333333313 MWh.
#   RTED --------------------- Day 0 Interval 285 Objective value: 336785.1727080962
# Energy cost: 8892.057018066584
# Reserve cost: 0.11569003333333372
# ------- Penalty summary
# PFR_up deficit: 0.24932333333331572 MWh.
#   RTED --------------------- Day 0 Interval 286 Objective value: 221255.4594563637
# Energy cost: 8554.688829665334
# Reserve cost: 0.10396003333333349
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 287 Objective value: 196004.8137696549
# Energy cost: 8236.403392121501
# Reserve cost: 0.0770442
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 288 Objective value: 195740.29325166825
# Energy cost: 7971.91853076817
# Reserve cost: 0.041387566666666674
# ------- Penalty summary
# Surplus of load: 17.12483333333334 MWh.
#
# ------------------ End MIDAS Scheduling -------------------

# %%
results_mode3 = run_mode3(solver_name = "gurobi",
                          prefix_dir = r"midass/operation/data/18_bus/",
                          psse_folder = r"18_bus_PSSE/",
                          case_name = r"Case1",
                          run_name = r"Case1_24hr_run_1_CL",
                          close_loop_flag = False, 
                          ess_interpolate_method = 1,
                          ess_dispatchable = False, 
                          verbose = True,
                          stop_by = 10)
# Out:
# ------------------ Start MIDAS Scheduling ---------------------
#
# -------------- Mode 3 ---------------------
# -------------- Preprocessing...
# Generator 0 flexibility type is determined by the start-up and shut-down time
# Generator 1 flexibility type is determined by the start-up and shut-down time
# Generator 2 flexibility type is determined by the start-up and shut-down time
# Generator 3 flexibility type is determined by the start-up and shut-down time
# -------------- Preprocessing complete.
#
#   DAUC --------------------- Day 0 Objective value: 236878.10136565747
# Energy cost: 236858.81337183554
# Reserve cost: 19.287993821740944
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 1 Objective value: 80530.64588780659
# Energy cost: 6981.092974473333
# Reserve cost: 0.3862466666666667
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 2 Objective value: 6978.910091197501
# Energy cost: 6978.489493697501
# Reserve cost: 0.4205975
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 3 Objective value: 6982.127575574999
# Energy cost: 6981.707740575
# Reserve cost: 0.419835
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 4 Objective value: 6984.522351789999
# Energy cost: 6984.10327929
# Reserve cost: 0.41907249999999996
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 5 Objective value: 6984.987319295
# Energy cost: 6984.569009295
# Reserve cost: 0.41830999999999996
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 6 Objective value: 6984.587074760834
# Energy cost: 6984.169527260834
# Reserve cost: 0.41754749999999996
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 7 Objective value: 6982.383199647502
# Energy cost: 6981.966414647502
# Reserve cost: 0.41678499999999996
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 8 Objective value: 6978.929161455833
# Energy cost: 6978.513138955834
# Reserve cost: 0.41602249999999996
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 9 Objective value: 6974.321384786666
# Energy cost: 6973.906124786667
# Reserve cost: 0.41525999999999996
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 10 Objective value: 6968.1084124925
# Energy cost: 6967.6939149925
# Reserve cost: 0.41449749999999996
# ------- Congrats! No penalty exists.
# -----------------------------------------------------------
# --------------Stopped as requested on Day 10---------------
# -----------------------------------------------------------
#
# ------------------ End MIDAS Scheduling -------------------

# %%
results_mode4 = run_mode4(solver_name = "gurobi",
                          prefix_dir = r"midass/operation/data/18_bus/",
                          psse_folder = r"18_bus_PSSE/",
                          case_name = r"Case1",
                          run_name = r"Case1_24hr_run_1_CL",
                          close_loop_flag = False,
                          ess_interpolate_method = 1,
                          ess_dispatchable = False, 
                          verbose = True,
                          stop_by = 20)
# Out:
# ------------------ Start MIDAS Scheduling ---------------------
#
# -------------- Mode 4 ---------------------
# -------------- Preprocessing...
# Generator 0 flexibility type is determined by the start-up and shut-down time
# Generator 1 flexibility type is determined by the start-up and shut-down time
# Generator 2 flexibility type is determined by the start-up and shut-down time
# Generator 3 flexibility type is determined by the start-up and shut-down time
# -------------- Preprocessing complete.
#
#   DAUC --------------------- Day 0 Objective value: 236878.10136565747
# Energy cost: 236858.81337183554
# Reserve cost: 19.287993821740944
# ------- Congrats! No penalty exists.
#   RTUC --------------------- Day 0 Interval 0 Objective value: 55813.34472927209
# Energy cost: 55809.240154363106
# Reserve cost: 4.104574908979638
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 1 Objective value: 80530.68140613992
# Energy cost: 6981.092974473333
# Reserve cost: 0.4217649999999999
# ------- Congrats! No penalty exists.
#   RTUC --------------------- Day 0 Interval 1 Objective value: 55646.395767557406
# Energy cost: 55642.31169052251
# Reserve cost: 4.08407703489798
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 2 Objective value: 6978.9104811975
# Energy cost: 6978.489493697501
# Reserve cost: 0.4209875
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 3 Objective value: 6982.127950575
# Energy cost: 6981.707740575
# Reserve cost: 0.42021000000000014
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 4 Objective value: 6984.522711789999
# Energy cost: 6984.10327929
# Reserve cost: 0.4194325000000001
# ------- Congrats! No penalty exists.
#   RTUC --------------------- Day 0 Interval 2 Objective value: 55536.57527377324
# Energy cost: 55532.5095973763
# Reserve cost: 4.065676396938766
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 5 Objective value: 6984.987643461666
# Energy cost: 6984.569009295
# Reserve cost: 0.41863416666666664
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 6 Objective value: 6984.587363094167
# Energy cost: 6984.169527260834
# Reserve cost: 0.41783583333333335
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 7 Objective value: 6982.383452147502
# Energy cost: 6981.966414647502
# Reserve cost: 0.4170375
# ------- Congrats! No penalty exists.
#   RTUC --------------------- Day 0 Interval 3 Objective value: 55545.2658629596
# Energy cost: 55541.21789702449
# Reserve cost: 4.047965935102058
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 8 Objective value: 6978.9293806225005
# Energy cost: 6978.513138955834
# Reserve cost: 0.4162416666666666
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 9 Objective value: 6974.32157062
# Energy cost: 6973.906124786667
# Reserve cost: 0.41544583333333324
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 10 Objective value: 6968.1085649925
# Energy cost: 6967.6939149925
# Reserve cost: 0.41464999999999996
# ------- Congrats! No penalty exists.
#   RTUC --------------------- Day 0 Interval 4 Objective value: 56042.21608617945
# Energy cost: 56037.73164832006
# Reserve cost: 4.484437859387782
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 11 Objective value: 6960.597565967499
# Energy cost: 6960.183620134166
# Reserve cost: 0.4139458333333333
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 12 Objective value: 6952.353367900833
# Energy cost: 6951.940126234166
# Reserve cost: 0.41324166666666656
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 13 Objective value: 6955.511781294166
# Energy cost: 6955.099243794166
# Reserve cost: 0.41253749999999995
# ------- Congrats! No penalty exists.
#   RTUC --------------------- Day 0 Interval 5 Objective value: 56727.9512755035
# Energy cost: 56723.16761053738
# Reserve cost: 4.7836649661225055
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 14 Objective value: 6947.911628203333
# Energy cost: 6947.499719036666
# Reserve cost: 0.4119091666666666
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 15 Objective value: 6940.701498744165
# Energy cost: 6940.290217910832
# Reserve cost: 0.4112808333333333
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 16 Objective value: 6929.6428473333335
# Energy cost: 6929.232194833334
# Reserve cost: 0.41065250000000003
# ------- Congrats! No penalty exists.
#   RTUC --------------------- Day 0 Interval 6 Objective value: 56767.88076641962
# Energy cost: 56763.10415838003
# Reserve cost: 4.776608039591778
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 17 Objective value: 6922.587704509167
# Energy cost: 6922.177593675834
# Reserve cost: 0.4101108333333334
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 18 Objective value: 6915.357034256666
# Energy cost: 6914.947465089999
# Reserve cost: 0.40956916666666676
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 19 Objective value: 6906.1150098175
# Energy cost: 6905.7059823175005
# Reserve cost: 0.40902750000000004
# ------- Congrats! No penalty exists.
#   RTUC --------------------- Day 0 Interval 7 Objective value: 57332.6823375946
# Energy cost: 57327.28095656949
# Reserve cost: 5.401381025102053
# ------- Congrats! No penalty exists.
#   RTED --------------------- Day 0 Interval 20 Objective value: 6898.623338768334
# Energy cost: 6898.214805435001
# Reserve cost: 0.40853333333333336
# ------- Congrats! No penalty exists.
# ----------------------------------------------------------------
# --------------Stopped as requested on Interval 20---------------
# ----------------------------------------------------------------
#
# ------------------ End MIDAS Scheduling -------------------
